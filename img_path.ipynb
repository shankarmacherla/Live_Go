# %% [markdown]
# EXTRACT IMAGES FROM EXCEL

# %%
import openpyxl
import os
from PIL import Image
from io import BytesIO
import re

# Load the Excel file
excel_path = "EXCELS/Cables/Cables_Original.xlsx"
output_folder = "EXCELS/Cables/Cables_images"
os.makedirs(output_folder, exist_ok=True)

# Open workbook
wb = openpyxl.load_workbook(excel_path, data_only=True)
sheet = wb.active

# Function to sanitize the fil
# \ename
def sanitize_filename(name):
    # Replace invalid characters with underscores or remove them
    name = re.sub(r'[<>:"/\\|?*]', '_', name)  # Replace invalid characters
    name = name.replace("\n", "_")  # Replace newline characters with underscore
    name = name.replace("\r", "_")  # Replace carriage return characters with underscore
    return name

# Extract images
image_map = {}  # Store row number → image file path mapping
image_index = 1

for img in sheet._images:
    if isinstance(img, openpyxl.drawing.image.Image):
        # Extract image data correctly
        img_bytes = img._data()
        
        # Convert to PIL image
        image_stream = BytesIO(img_bytes)
        pil_img = Image.open(image_stream)

        # Get the name from a column (e.g., column A is assumed here, adjust as needed)
        name_cell = sheet.cell(row=image_index + 1, column=1)  # Adjust column as needed
        image_name = f"{name_cell.value}.png"  # Use the value in the cell as the name

        # Sanitize the image name
        sanitized_name = sanitize_filename(image_name)

        # Convert image to RGB if it's in CMYK mode
        if pil_img.mode == 'CMYK':
            pil_img = pil_img.convert('RGB')

        # Save the image with the new sanitized name
        image_path = os.path.join(output_folder, sanitized_name)
        pil_img.save(image_path)


        # Store mapping (assuming images align with row numbers)
        row_number = image_index + 1  # Adjust row mapping if needed
        image_map[row_number] = image_path
        image_index += 1

print(f"Extracted {len(image_map)} images to {output_folder}")
print(image_map)
# Out:
# Extracted 477 images to EXCELS/Cables/Cables_images
# {2: 'EXCELS/Cables/Cables_images\\Black Cat6 550MHz RJ45 Network Patch Cable (Bootless).png', 3: 'EXCELS/Cables/Cables_images\\Blue Cat6 Network Patch Cable Bootless 550mhz.png', 4: 'EXCELS/Cables/Cables_images\\White Cat6 550MHz Network Patch Cable (Bootless)_.png', 5: 'EXCELS/Cables/Cables_images\\Grey Cat6 550MHz Network Patch Cable (Bootless).png', 6: 'EXCELS/Cables/Cables_images\\Red Cat6 550MHz Network Patch Cable (Bootless).png', 7: 'EXCELS/Cables/Cables_images\\Green Cat6 550MHz Network Patch Cable (Bootless).png', 8: 'EXCELS/Cables/Cables_images\\Violet Cat6 550MHz Network Patch Cable (Bootless).png', 9: 'EXCELS/Cables/Cables_images\\Orange Cat6 550MHz Network Patch Cable (Bootless).png', 10: 'EXCELS/Cables/Cables_images\\Cat6 550MHz Network Patch Cable Aqua (Bootless).png', 11: 'EXCELS/Cables/Cables_images\\Cat6 550MHz Network Patch Cable Brown (Bootless).png', 12: 'EXCELS/Cables/Cables_images\\Cat6 550MHz RJ45 Network Patch Cable Pink (Bootless).png', 13: 'EXCELS/Cables/Cables_images\\Cat6 550MHz Network Patch Cable Yellow (Bootless).png', 14: 'EXCELS/Cables/Cables_images\\Cat6 Ethernet Patch Cable Snagless Boot - Black.png', 15: 'EXCELS/Cables/Cables_images\\Cat6 Ethernet Patch Cable Snagless Boot -
# %% [markdown]
# FOR FOLDER

# %%
import openpyxl
import os
from PIL import Image
from io import BytesIO
import re

# Path to the folder containing your Excel files
excel_folder = r"EXCELS\Rack\Rack Vendors"
output_folder = r"EXCELS\Rack\Rack_images"
os.makedirs(output_folder, exist_ok=True)

# Function to sanitize the filename
def sanitize_filename(name):
    name = re.sub(r'[<>:"/\\|?*]', '_', name)
    name = name.replace("\n", "_")
    name = name.replace("\r", "_")
    return name

# Function to extract images from a single Excel file
def extract_images_from_excel(excel_path):
    wb = openpyxl.load_workbook(excel_path, data_only=True)
    sheet = wb.active
    image_map = {}
    image_index = 1

    for img in sheet._images:
        if isinstance(img, openpyxl.drawing.image.Image):
            # Extract image data
            img_bytes = img._data()

            # Convert to PIL image
            image_stream = BytesIO(img_bytes)
            pil_img = Image.open(image_stream)

            # Get the name from a column (assume column A here)
            name_cell = sheet.cell(row=image_index + 1, column=1)
            image_name = f"{name_cell.value}.png"  # Name the image based on the cell value

            # Sanitize the image name
            sanitized_name = sanitize_filename(image_name)

            # Convert image to RGB if in CMYK mode
            if pil_img.mode == 'CMYK':
                pil_img = pil_img.convert('RGB')

            # Save the image with the sanitized name
            image_path = os.path.join(output_folder, sanitized_name)
            pil_img.save(image_path)

            # Store the image mapping (row -> image path)
            row_number = image_index + 1
            image_map[row_number] = image_path
            image_index += 1

    return image_map

# Loop through all Excel files in the folder
image_maps = {}

for excel_file in os.listdir(excel_folder):
    if excel_file.endswith(".xlsx"):
        excel_path = os.path.join(excel_folder, excel_file)
        print(f"Processing {excel_file}...")
        image_map = extract_images_from_excel(excel_path)
        image_maps[excel_file] = image_map

print(f"Processed all files in {excel_folder}")
# Out:
# Processing Black Box.xlsx...
# Processing Eaton Corporation.xlsx...
# Processing Finen.xlsx...
# Processing Great Lakes Data Racks & Cabinets.xlsx...
# Processing Hewlett Packard Enterprise(HPE).xlsx...
# Processing Kendall Howard.xlsx...
# Processing Legrand.xlsx...
# Processing NETRACK.xlsx...
# Processing Schneider.xlsx...
# Processed all files in EXCELS\Rack\Rack Vendors

# %% [markdown]
# MODIFY THE EXCEL WITH THE PATHS

# %%
import os
import pandas as pd

# Define the folder path where images are stored
folder_path = "EXCELS/Cables/cable_images"

# Define the output file path
output_file_path = "EXCELS/Cables/cable.xlsx"

# Check if the output directory exists, and create it if not
output_dir = os.path.dirname(output_file_path)
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Load the uploaded Excel file
df = pd.read_excel("EXCELS/Cables/Cables_Original.xlsx", engine='openpyxl')

# Update the 'Image' column with the full file paths
df['Image'] = df['Name'].apply(lambda name: os.path.join(folder_path, f"{name}.png"))

# Save the updated DataFrame back to Excel
df.to_excel(output_file_path, index=False, engine='openpyxl')

print(f"File has been saved successfully to {output_file_path}")
# Out:
# File has been saved successfully to EXCELS/Cables/cable.xlsx

# %%
import os
import pandas as pd

# Define the folder paths
input_folder_path = "F:/UI/EXCELS/Rack/Rack Vendors"  # Folder containing the Excel files
image_folder_path = "F:/UI/EXCELS/Rack/Rack_images"  # Folder containing the images
output_folder_path = "F:/UI/EXCELS/Rack/Rack_updated"  # Folder where updated Excel files will be saved

# Ensure the output directory exists
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Loop through all Excel files in the input folder
for excel_file in os.listdir(input_folder_path):
    if excel_file.endswith('.xlsx'):
        # Construct full file paths
        input_file_path = os.path.join(input_folder_path, excel_file)
        output_file_path = os.path.join(output_folder_path, excel_file)
        
        # Load the Excel file
        df = pd.read_excel(input_file_path, engine='openpyxl')
        
        # Update the 'Image' column with the full file paths
        df['Image'] = df['Name'].apply(lambda name: os.path.join(image_folder_path, f"{name}.png"))
        
        # Save the updated DataFrame back to Excel
        df.to_excel(output_file_path, index=False, engine='openpyxl')
        
        print(f"Updated file saved: {output_file_path}")
# Out:
# Updated file saved: F:/UI/EXCELS/Rack/Rack_updated\Black Box.xlsx
# Updated file saved: F:/UI/EXCELS/Rack/Rack_updated\Eaton Corporation.xlsx
# Updated file saved: F:/UI/EXCELS/Rack/Rack_updated\Finen.xlsx
# Updated file saved: F:/UI/EXCELS/Rack/Rack_updated\Great Lakes Data Racks & Cabinets.xlsx
# Updated file saved: F:/UI/EXCELS/Rack/Rack_updated\Hewlett Packard Enterprise(HPE).xlsx
# Updated file saved: F:/UI/EXCELS/Rack/Rack_updated\Kendall Howard.xlsx
# Updated file saved: F:/UI/EXCELS/Rack/Rack_updated\Legrand.xlsx
# Updated file saved: F:/UI/EXCELS/Rack/Rack_updated\NETRACK.xlsx
# Updated file saved: F:/UI/EXCELS/Rack/Rack_updated\Schneider.xlsx

# %%
import pandas as pd
import os

# Define the folder containing the Excel files
folder_path = r"EXCELS\Rack\Rack_updated"  # Change this to your actual folder path

# List all Excel files in the folder
files = [f for f in os.listdir(folder_path) if f.endswith('.xlsx') or f.endswith('.xls')]

# Initialize an empty DataFrame
combined_data = pd.DataFrame()

# Loop through each file and append its data to the combined DataFrame
for file in files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_excel(file_path)
    combined_data = pd.concat([combined_data, df], ignore_index=True)

# Export the combined data to a new Excel file
output_path = os.path.join(folder_path, 'Rack.xlsx')
combined_data.to_excel(output_path, index=False)

print(f'Combined Excel file saved at: {output_path}')
# Out:
# Combined Excel file saved at: EXCELS\Rack\Rack_updated\Rack.xlsx

# %%
import os
import pandas as pd
import shutil
import re

# Define paths


import os
import pandas as pd
import re
import shutil

# --- CONFIGURE THESE PATHS ---
excel_path = r'F:\UI\EXCELS\Switch\Switches.xlsx'
images_folder = r'F:\UI\EXCELS\Switch\Switch_images'
output_folder = r'F:\UI\EXCELS\Switch\Renamed_kimages' 

# --- Normalization function ---
def normalize(name):
    return re.sub(r'\W+', '', str(name).lower().strip())

# --- Sanitization function for filenames ---
def sanitize_filename(name):
    name = str(name)  # Ensure it's a string
    name = name.replace('\n', ' ').replace('\r', ' ')
    return re.sub(r'[\\/*?:"<>|]', '', name).strip()

# --- Read Excel file ---
df = pd.read_excel(excel_path)

# Make sure 'Name' column exists
if 'Name' not in df.columns:
    raise ValueError("Excel file must contain a 'Name' column.")

# Normalize names from Excel into a dictionary {normalized_name: original_name}
name_map = {normalize(name): name for name in df['Name'] if pd.notnull(name)}

# --- Process and rename images ---
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

for filename in os.listdir(image_folder):
    base, ext = os.path.splitext(filename)
    normalized_img = normalize(base)
    match = name_map.get(normalized_img)

    if match:
        clean_name = sanitize_filename(match) + ext.lower()
        output_path = os.path.join(output_folder, clean_name)
        try:
            shutil.copy2(os.path.join(image_folder, filename), output_path)
            print(f"Renamed and copied: {filename} → {clean_name}")
        except Exception as e:
            print(f"Error copying {filename}: {e}")
    else:
        print(f"No match for: {filename}")
# Out:
# Renamed and copied: 16801.png → 16801.png
# Renamed and copied: 16802.png → 16802.png
# Renamed and copied: 16803.png → 16803.png
# Renamed and copied: 16804.png → 16804.png
# Renamed and copied: 2526T-PWRAL250011-E6.png → 2526T-PWRAL250011-E6.png
# Renamed and copied: 2526T-PWRAL251511-E6.png → 2526T-PWRAL251511-E6.png
# Renamed and copied: 2526TAL250001-E6.png → 2526TAL250001-E6.png
# Renamed and copied: 2526tal250001e6.png → 2526TAL250001-E6.png
# Renamed and copied: 2526TAL251501-E6.png → 2526TAL251501-E6.png
# Renamed and copied: 2526tal251501e6.png → 2526TAL251501-E6.png
# Renamed and copied: 2526tpwral250011e6.png → 2526T-PWRAL250011-E6.png
# Renamed and copied: 2526tpwral251511e6.png → 2526T-PWRAL251511-E6.png
# Renamed and copied: 2550T AL250002-E6.png → 2550T AL250002-E6.png
# Renamed and copied: 2550T-PWRAL250012-E6.png → 2550T-PWRAL250012-E6.png
# Renamed and copied: 2550T-PWRAL251512-E6.png → 2550T-PWRAL251512-E6.png
# Renamed and copied: 2550tal250002e6.png → 2550T AL250002-E6.png
# Renamed and copied: 2550TAL251502-E6.png → 2550TAL251502-E6.png
# Renamed and copied: 2550tal251502e6.png → 2550TAL251502-E6.png
# Renamed and copied: 2550tpwral250012e6.png → 2550T-PWRAL250012-E6.png
# Renamed and copied: 2550tpwral251512e6.png → 2550T-PWRAL251512-E6.png
# Renamed and copied: 25GE Interface Card.png → 25GE Interface Card.png
# Renamed and copied: 25geinterfacecard.png → 25GE Interface Card.png
# Renamed and copied: 2960CX-8PC-L.png → 2960CX-8PC-L.png
# Renamed and copied: 2960CX-8TC-L.png → 2960CX-8TC-L.png
# Renamed and copied: 2960cx8pcl.png → 2960CX-8PC-L.png
# Renamed and copied: 2960cx8tcl.png → 2960CX-8TC-L.png
# Renamed and copied: 3510GT PWR+AL350014-E6.png → 3510GT PWR+AL350014-E6.png
# Renamed and copied: 3510GTAL350004-E6.png → 3510GTAL350004-E6.png
# Renamed and copied: 3510gtal350004e6.png → 3510GTAL350004-E6.png
# Renamed and copied: 3510gtpwral350014e6.png → 3510GT PWR+AL350014-E6.png
# Renamed and copied: 3524GT-PWR+AL350015-E6.png → 3524GT-PWR+AL350015-E6.png
# Renamed and copied: 3524GTAL350005-E6.png → 3524GTAL350005-E6.png
# Renamed and copied: 3524gtal350005e6.png → 3524GTAL350005-E6.png
# Renamed and copied: 3524gtpwral350015e6.png → 3524GT-PWR+AL350015-E6.png
# Renamed and copied: 88654c.png → 8865-4C.png
# Renamed and copied: 8865san4c.png → 8865-SAN-4C.png
# Renamed and copied: 887524bq8dq.png → 8875-24BQ8DQ.png
# Renamed and copied: 9012chassisec1402001e6.png → 9012 Chassis EC1402001-E6.png
# Renamed and copied: 9240.png → 9240.png
# Renamed and copied: 96LBS.png → 96LBS.png
# Renamed and copied: 985532dq.png → 9855-32DQ.png
# Renamed and copied: 98654c.png → 9865-4C.png
# Renamed and copied: Aggregation.png → Aggregation.png
# Renamed and copied: al700001be6.png → AL700001B-E6.png
# Renamed and copied: aruba253024gpoeswitchj9773aj9773acm1.png → Aruba 2530-24G-PoE+ Switch (J9773A) (J9773ACM1).png
# Renamed and copied: aruba253024gswitchj9776a.png → Aruba 2530-24G Switch (J9776A).png
# Renamed and copied: aruba253024poeswitchj9779a.png → Aruba 2530-24-PoE+ Switch (J9779A).png
# Renamed and copied: aruba253024switchj9782a.png → Aruba 2530-24 Switch (J9782A).png
# Renamed and copied: aruba253048gpoeswitchj9772aj9772acm1.png → Aruba 2530-48G-PoE+ Switch (J9772A) (J9772ACM1).png
# Renamed and copied: aruba253048gswitchj9775a.png → Aruba 2530-48G Switch (J9775A).png
# Renamed and copied: aruba253048poeswitchj9778a.png → Aruba 2530-48-PoE+ Switch (J9778A).png
# Renamed and copied: aruba253048switchj9781a.png → Aruba 2530-48 Switch (J9781A).png
# Renamed and copied: aruba25308gpoeswitchj9774aj9774acm1.png → Aruba 2530-8G-PoE+ Switch (J9774A) (J9774ACM1).png
# Renamed and copied: aruba25308gswitchj9777a.png → Aruba 2530-8G Switch (J9777A).png
# Renamed and copied: aruba25308poeinternalpsswitchjl070a.png → Aruba 2530-8-PoE+ Internal PS Switch (JL070A).png
# Renamed and copied: aruba25308poeswitchj9780a.png → Aruba 2530-8-PoE+ Switch (J9780A).png
# Renamed and copied: aruba25308switchj9783a.png → Aruba 2530-8 Switch (J9783A).png
# Renamed and copied: aruba5406r16portsfpnopsuv3zl2switchjl095a.png → Aruba 5406R 16-port SFP+ (No PSU) v3 zl2 Switch (JL095A).png
# Renamed and copied: aruba5406r44gtpoeand4portsfpnopsuv3zl2switchjl003a.png → Aruba 5406R 44GT PoE+ and 4-port SFP+ (No PSU) v3 zl2 Switch (JL003A).png
# No match for: aruba5406r8port12.png
# Renamed and copied: aruba5412r92gtpoeand4portsfpnopsuv3zl2switchjl001a.png → Aruba 5412R 92GT PoE+ and 4-port SFP+ (No PSU) v3 zl2 Switch (JL001A).png
# Renamed and copied: as461030p.png → AS4610-30P.png
# Renamed and copied: as461030t.png → AS4610-30T.png
# Renamed and copied: as461054pv1.png → AS4610-54P v1.png
# Renamed and copied: as461054tv1oras461054tb.png → AS4610-54T v1 OR AS4610-54T (B).png
# Renamed and copied: as581254tec.png → AS5812-54T-EC.png
# Renamed and copied: as581254xec.png → AS5812-54X-EC.png
# Renamed and copied: AWE-7220RP-5TH-2S-F.png → AWE-7220RP-5TH-2S-F.png
# Renamed and copied: AWE-7230R-4TX-4S-F.png → AWE-7230R-4TX-4S-F.png
# Renamed and copied: AWE-7250R-16S-F.png → AWE-7250R-16S-F.png
# Renamed and copied: brocade200eswitch.png → Brocade 200E Switch.png
# Renamed and copied: brocade300switch.png → Brocade 300 Switch.png
# Renamed and copied: brocade5000switch.png → Brocade 5000 Switch.png
# Renamed and copied: brocade5300switch.png → Brocade 5300 Switch.png
# Renamed and copied: brocade6505switch.png → Brocade 6505 Switch.png
# Renamed and copied: brocade6520switch.png → Brocade 6520 Switch.png
# Renamed and copied: brocade7810extensionswitch.png → Brocade 7810 Extension Switch.png
# Renamed and copied: brocade7850extensionswitch.png → Brocade 7850 Extension Switch.png
# Renamed and copied: brocadeg610switch.png → Brocade G610 Switch.png
# Renamed and copied: brocadeg620switch.png → Brocade G620 Switch.png
# Renamed and copied: brocadeg630switch.png → Brocade G630 Switch.png
# Renamed and copied: brocadeg710switch.png → Brocade G710 Switch.png
# Renamed and copied: brocadeg720switch.png → Brocade G720 Switch.png
# Renamed and copied: brocadeg730switch.png → Brocade G730 Switch.png
# Renamed and copied: c100016fp2gl.png → C1000-16FP-2G-L.png
# Renamed and copied: c100016p2gl.png → C1000-16P-2G-L.png
# Renamed and copied: c100016pe2gl.png → C1000-16P-E-2G-L.png
# Renamed and copied: c100016t2gl.png → C1000-16T-2G-L.png
# Renamed and copied: c100016te2gl.png → C1000-16T-E-2G-L.png
# Renamed and copied: c100024fp4gl.png → C1000-24FP-4G-L.png
# Renamed and copied: c100024fp4xl.png → C1000-24FP-4X-L.png
# Renamed and copied: c100024p4gl.png → C1000-24P-4G-L.png
# Renamed and copied: c100024p4xl.png → C1000-24P-4X-L.png
# Renamed and copied: c100024t4gl.png → C1000-24T-4G-L.png
# Renamed and copied: c100024t4xl.png → C1000-24T-4X-L.png
# Renamed and copied: c100048fp4gl.png → C1000-48FP-4G-L.png
# Renamed and copied: c100048fp4xl.png → C1000-48FP-4X-L.png
# Renamed and copied: c100048p4gl.png → C1000-48P-4G-L.png
# Renamed and copied: c100048p4xl.png → C1000-48P-4X-L.png
# Renamed and copied: c100048t4gl.png → C1000-48T-4G-L.png
# Renamed and copied: c100048t4xl.png → C1000-48T-4X-L.png
# Renamed and copied: c10008fp2gl.png → C1000-8FP-2G-L.png
# Renamed and copied: c10008fpe2gl.png → C1000-8FP-E-2G-L.png
# Renamed and copied: c10008p2gl.png → C1000-8P-2G-L.png
# Renamed and copied: c10008pe2gl.png → C1000-8P-E-2G-L.png
# Renamed and copied: c10008t2gl.png → C1000-8T-2G-L.png
# Renamed and copied: c10008te2gl.png → C1000-8T-E-2G-L.png
# Renamed and copied: c1000fe24p4gl.png → C1000FE-24P-4G-L.png
# Renamed and copied: c1000fe24t4gl.png → C1000FE-24T-4G-L.png
# Renamed and copied: c1000fe48p4gl.png → C1000FE-48P-4G-L.png
# Renamed and copied: c1000fe48t4gl.png → C1000FE-48T-4G-L.png
# Renamed and copied: c1048pon.png → C1048P-ON.png
# Renamed and copied: c120016p2g.png → C1200-16P-2G.png
# Renamed and copied: c120024fp4g.png → C1200-24FP-4G.png
# Renamed and copied: c120024fp4x.png → C1200-24FP-4X.png
# Renamed and copied: c120024p4g.png → C1200-24P-4G.png
# Renamed and copied: c120024p4x.png → C1200-24P-4X.png
# Renamed and copied: c120048p4g.png → C1200-48P-4G.png
# Renamed and copied: c120048p4x.png → C1200-48P-4X.png
# Renamed and copied: c12008fp2g.png → C1200-8FP-2G.png
# Renamed and copied: c12008pe2g.png → C1200-8P-E-2G.png
# Renamed and copied: c12008td.png → C1200-8T-D.png
# Renamed and copied: c130012xs.png → C1300-12XS.png
# Renamed and copied: c130012xt2x.png → C1300-12XT-2X.png
# Renamed and copied: c130016fp2g.png → C1300-16FP-2G.png
# Renamed and copied: c130016p2g.png → C1300-16P-2G.png
# Renamed and copied: c130016p4x.png → C1300-16P-4X.png
# Renamed and copied: c130016t2g.png → C1300-16T-2G.png
# Renamed and copied: c130016xts.png → C1300-16XTS.png
# Renamed and copied: c130024fp4g.png → C1300-24FP-4G.png
# Renamed and copied: c130024fp4x.png → C1300-24FP-4X.png
# Renamed and copied: c130024mgp4x.png → C1300-24MGP-4X.png
# Renamed and copied: c130024p4g.png → C1300-24P-4G.png
# Renamed and copied: c130024p4x.png → C1300-24P-4X.png
# Renamed and copied: c130024t4g.png → C1300-24T-4G.png
# Renamed and copied: c130024t4x.png → C1300-24T-4X.png
# Renamed and copied: c130024xs.png → C1300-24XS.png
# Renamed and copied: c130024xts.png → C1300-24XTS.png
# Renamed and copied: c130048fp4g.png → C1300-48FP-4G.png
# Renamed and copied: c130048fp4x.png → C1300-48FP-4X.png
# Renamed and copied: c130048mgp4x.png → C1300-48MGP-4X.png
# Renamed and copied: c130048p4g.png → C1300-48P-4G.png
# Renamed and copied: c130048p4x.png → C1300-48P-4X.png
# Renamed and copied: c130048t4x.png → C1300-48T-4X.png
# Renamed and copied: c13004t4g.png → C1300-4T-4G.png
# Renamed and copied: c13008fp2g.png → C1300-8FP-2G.png
# Renamed and copied: c13008mgp2x.png → C1300-8MGP-2X.png
# Renamed and copied: c13008pe2g.png → C1300-8P-E-2G.png
# Renamed and copied: c13008te2g.png → C1300-8T-E-2G.png
# Renamed and copied: c3560cx12pcs.png → C3560CX-12PC-S.png
# Renamed and copied: c3560cx12pds.png → C3560CX-12PD-S.png
# Renamed and copied: c3560cx8pcs.png → C3560CX-8PC-S.png
# Renamed and copied: c3560cx8pts.png → C3560CX-8PT-S.png
# Renamed and copied: c3560cx8tcs.png → C3560CX-8TC-S.png
# Renamed and copied: c3560cx8xpds.png → C3560CX-8XPD-S.png
# Renamed and copied: c680016p10g.png → C6800-16P10G.png
# Renamed and copied: c680016p10gxl.png → C6800-16P10G-XL.png
# Renamed and copied: c680032p10g.png → C6800-32P10G.png
# Renamed and copied: c680032p10gxl.png → C6800-32P10G-XL.png
# Renamed and copied: c68008p10g.png → C6800-8P10G.png
# Renamed and copied: c68008p10gxl.png → C6800-8P10G-XL.png
# Renamed and copied: C7008.png → C7008.png
# Renamed and copied: C9000.png → C9000.png
# Renamed and copied: c920024p.png → C9200-24P.png
# Renamed and copied: c920024pb.png → C9200-24PB.png
# Renamed and copied: c920024t.png → C9200-24T.png
# Renamed and copied: c920048p.png → C9200-48P.png
# Renamed and copied: c920048pl.png → C9200-48PL.png
# Renamed and copied: c920048t.png → C9200-48T.png
# Renamed and copied: c9200l24p4g.png → C9200L-24P-4G.png
# Renamed and copied: c9200l24p4x.png → C9200L-24P-4X.png
# Renamed and copied: c9200l24pxg2y.png → C9200L-24PXG-2Y.png
# Renamed and copied: c9200l24pxg4x.png → C9200L-24PXG-4X.png
# Renamed and copied: c9200l24t4g.png → C9200L-24T-4G.png
# Renamed and copied: c9200l24t4x.png → C9200L-24T-4X.png
# Renamed and copied: c9200l48p4g.png → C9200L-48P-4G.png
# Renamed and copied: c9200l48p4x.png → C9200L-48P-4X.png
# Renamed and copied: c9200l48pl4g.png → C9200L-48PL-4G.png
# Renamed and copied: c9200l48pxg2y.png → C9200L-48PXG-2Y.png
# Renamed and copied: c9200l48pxg4x.png → C9200L-48PXG-4X.png
# Renamed and copied: c9200l48t4g.png → C9200L-48T-4G.png
# Renamed and copied: c9200l48t4x.png → C9200L-48T-4X.png
# Renamed and copied: c930024h.png → C9300-24H.png
# Renamed and copied: c930024p.png → C9300-24P.png
# Renamed and copied: c930024pm.png → C9300-24P-M.png
# Renamed and copied: c930024s.png → C9300-24S.png
# Renamed and copied: c930024sm.png → C9300-24S-M.png
# Renamed and copied: c930024t.png → C9300-24T.png
# Renamed and copied: c930024tm.png → C9300-24T-M.png
# Renamed and copied: c930024u.png → C9300-24U.png
# Renamed and copied: c930024ub.png → C9300-24UB.png
# Renamed and copied: c930024um.png → C9300-24U-M.png
# Renamed and copied: c930024ux.png → C9300-24UX.png
# Renamed and copied: c930024uxb.png → C9300-24UXB.png
# Renamed and copied: c930024uxm.png → C9300-24UX-M.png
# Renamed and copied: c930048h.png → C9300-48H.png
# Renamed and copied: c930048p.png → C9300-48P.png
# Renamed and copied: c930048pm.png → C9300-48P-M.png
# Renamed and copied: c930048s.png → C9300-48S.png
# Renamed and copied: c930048sm.png → C9300-48S-M.png
# Renamed and copied: c930048t.png → C9300-48T.png
# Renamed and copied: c930048tm.png → C9300-48T-M.png
# Renamed and copied: c930048u.png → C9300-48U.png
# Renamed and copied: c930048ub.png → C9300-48UB.png
# Renamed and copied: c930048um.png → C9300-48U-M.png
# Renamed and copied: c930048un.png → C9300-48UN.png
# Renamed and copied: c930048unm.png → C9300-48UN-M.png
# Renamed and copied: c930048uxm.png → C9300-48UXM.png
# Renamed and copied: c930048uxmm.png → C9300-48UXM-M.png
# Renamed and copied: c9300l24p4g.png → C9300L-24P-4G.png
# Renamed and copied: c9300l24p4x.png → C9300L-24P-4X.png
# Renamed and copied: c9300l24t4g.png → C9300L-24T-4G.png
# Renamed and copied: c9300l24t4x.png → C9300L-24T-4X.png
# Renamed and copied: c9300l24uxg2q.png → C9300L-24UXG-2Q.png
# Renamed and copied: c9300l24uxg4x.png → C9300L-24UXG-4X.png
# Renamed and copied: c9300l48p4g.png → C9300L-48P-4G.png
# Renamed and copied: c9300l48p4x.png → C9300L-48P-4X.png
# Renamed and copied: c9300l48pf4g.png → C9300L-48PF-4G.png
# Renamed and copied: c9300l48pf4x.png → C9300L-48PF-4X.png
# Renamed and copied: c9300l48t4g.png → C9300L-48T-4G.png
# Renamed and copied: c9300l48t4x.png → C9300L-48T-4X.png
# Renamed and copied: c9300l48uxg2q.png → C9300L-48UXG-2Q.png
# Renamed and copied: c9300l48uxg4x.png → C9300L-48UXG-4X.png
# Renamed and copied: c9300lm24u4y.png → C9300LM-24U-4Y.png
# Renamed and copied: c9300lm48t4y.png → C9300LM-48T-4Y.png
# Renamed and copied: c9300lm48u4y.png → C9300LM-48U-4Y.png
# Renamed and copied: c9300lm48ux4y.png → C9300LM-48UX-4Y.png
# Renamed and copied: c9300x12y.png → C9300X-12Y.png
# Renamed and copied: c9300x24hx.png → C9300X-24HX.png
# Renamed and copied: c9300x24y.png → C9300X-24Y.png
# Renamed and copied: c9300x48hx.png → C9300X-48HX.png
# Renamed and copied: c9300x48hxn.png → C9300X-48HXN.png
# Renamed and copied: c9300x48tx.png → C9300X-48TX.png
# Renamed and copied: c94010r10slotchassis.png → C94010R(10-slot chassis).png
# Renamed and copied: c9404r4slotchassis.png → C9404R(4-slot chassis).png
# Renamed and copied: c9407r7slotchassis.png → C9407R(7-slot chassis).png
# Renamed and copied: c950016x.png → C9500-16X.png
# Renamed and copied: c950024y4c.png → C9500-24Y4C.png
# Renamed and copied: c950028c8d.png → C9500-28C8D.png
# Renamed and copied: c950032c.png → C9500-32C.png
# Renamed and copied: c950032qc.png → C9500-32QC.png
# Renamed and copied: c950048y4c.png → C9500-48Y4C.png
# Renamed and copied: c950060l4d.png → C9500-60L4D.png
# Renamed and copied: c9606r6slotchasis.png → C9606R(6-slot chasis).png
# Renamed and copied: catalyst296024lcs.png → Catalyst 2960-24LC-S.png
# Renamed and copied: catalyst296024pcs.png → Catalyst 2960-24PC-S.png
# Renamed and copied: catalyst296024s.png → Catalyst 2960-24-S.png
# Renamed and copied: catalyst296024tcs.png → Catalyst 2960-24TC-S.png
# Renamed and copied: catalyst296048psts.png → Catalyst 2960-48PST-S.png
# Renamed and copied: catalyst296048tcs.png → Catalyst 2960-48TC-S.png
# Renamed and copied: catalyst296048tts.png → Catalyst 2960-48TT-S.png
# Renamed and copied: catalyst29608tcs.png → Catalyst 2960-8TC-S.png
# Renamed and copied: catalyst2960s24tss.png → Catalyst 2960S-24TS-S.png
# Renamed and copied: catalyst2960s48tss.png → Catalyst 2960S-48TS-S.png
# Renamed and copied: catalyst2960x24pdl.png → Catalyst 2960X-24PD-L.png
# Renamed and copied: catalyst2960x24psl.png → Catalyst 2960X-24PS-L.png
# Renamed and copied: catalyst2960x24psql.png → Catalyst 2960X-24PSQ-L.png
# Renamed and copied: catalyst2960x48fpdl.png → Catalyst 2960X-48FPD-L.png
# Renamed and copied: catalyst2960x48fpsl.png → Catalyst 2960X-48FPS-L.png
# Renamed and copied: catalyst2960x48lpdl.png → Catalyst 2960X-48LPD-L.png
# Renamed and copied: catalyst2960x48lpsl.png → Catalyst 2960X-48LPS-L.png
# Renamed and copied: catalyst2960xr24pdi.png → Catalyst 2960XR-24PD-I.png
# Renamed and copied: catalyst2960xr24psi.png → Catalyst 2960XR-24PS-I.png
# Renamed and copied: catalyst2960xr48fpdi.png → Catalyst 2960XR-48FPD-I.png
# Renamed and copied: catalyst2960xr48fpsi.png → Catalyst 2960XR-48FPS-I.png
# Renamed and copied: catalyst2960xr48lpdi.png → Catalyst 2960XR-48LPD-I.png
# Renamed and copied: catalyst2960xr48lpsi.png → Catalyst 2960XR-48LPS-I.png
# Renamed and copied: catalyst4503e.png → Catalyst 4503-E.png
# Renamed and copied: catalyst4506e.png → Catalyst 4506-E.png
# Renamed and copied: catalyst4507re.png → Catalyst 4507R+E.png
# Renamed and copied: catalyst4510re.png → Catalyst 4510R+E.png
# Renamed and copied: catalyst940010slot.png → Catalyst 9400 10-slot.png
# Renamed and copied: catalyst94004slot.png → Catalyst 9400 4-slot.png
# Renamed and copied: catalyst94007slot.png → Catalyst 9400 7-slot.png
# Renamed and copied: catalystdigitalbuildingseriesswitch8p.png → Catalyst Digital Building Series Switch-8P.png
# Renamed and copied: catalystdigitalbuildingseriesswitch8u.png → Catalyst Digital Building Series Switch-8U.png
# Renamed and copied: cbs11016pp.png → CBS110-16PP.png
# Renamed and copied: cbs11016t.png → CBS110-16T.png
# Renamed and copied: cbs11024pp.png → CBS110-24PP.png
# Renamed and copied: cbs11024t.png → CBS110-24T.png
# Renamed and copied: cbs1105td.png → CBS110-5T-D.png
# Renamed and copied: cbs1108ppd.png → CBS110-8PP-D.png
# Renamed and copied: cbs1108td.png → CBS110-8T-D.png
# Renamed and copied: cbs22016p2g.png → CBS220-16P-2G.png
# Renamed and copied: cbs22016t2g.png → CBS220-16T-2G.png
# Renamed and copied: cbs22024fp4g.png → CBS220-24FP-4G.png
# Renamed and copied: cbs22024fp4x.png → CBS220-24FP-4X.png
# Renamed and copied: cbs22024p4g.png → CBS220-24P-4G.png
# Renamed and copied: cbs22024p4x.png → CBS220-24P-4X.png
# Renamed and copied: cbs22024t4g.png → CBS220-24T-4G.png
# Renamed and copied: cbs22024t4x.png → CBS220-24T-4X.png
# Renamed and copied: cbs22048fp4x.png → CBS220-48FP-4X.png
# Renamed and copied: cbs22048p4g.png → CBS220-48P-4G.png
# Renamed and copied: cbs22048p4x.png → CBS220-48P-4X.png
# Renamed and copied: cbs22048t4g.png → CBS220-48T-4G.png
# Renamed and copied: cbs22048t4x.png → CBS220-48T-4X.png
# Renamed and copied: cbs2208fpe2g.png → CBS220-8FP-E-2G.png
# Renamed and copied: cbs2208pe2g.png → CBS220-8P-E-2G.png
# Renamed and copied: cbs2208te2g.png → CBS220-8T-E-2G.png
# Renamed and copied: cbs25016p2g.png → CBS250-16P-2G.png
# Renamed and copied: cbs25016t2g.png → CBS250-16T-2G.png
# Renamed and copied: cbs25024fp4g.png → CBS250-24FP-4G.png
# Renamed and copied: cbs25024fp4x.png → CBS250-24FP-4X.png
# Renamed and copied: cbs25024p4g.png → CBS250-24P-4G.png
# Renamed and copied: cbs25024p4x.png → CBS250-24P-4X.png
# Renamed and copied: cbs25024pp4g.png → CBS250-24PP-4G.png
# Renamed and copied: cbs25024t4g.png → CBS250-24T-4G.png
# Renamed and copied: cbs25024t4x.png → CBS250-24T-4X.png
# Renamed and copied: cbs25048p4g.png → CBS250-48P-4G.png
# Renamed and copied: cbs25048p4x.png → CBS250-48P-4X.png
# Renamed and copied: cbs25048pp4g.png → CBS250-48PP-4G.png
# Renamed and copied: cbs25048t4g.png → CBS250-48T-4G.png
# Renamed and copied: cbs25048t4x.png → CBS250-48T-4X.png
# Renamed and copied: cbs2508fpe2g.png → CBS250-8FP-E-2G.png
# Renamed and copied: cbs2508pe2g.png → CBS250-8P-E-2G.png
# Renamed and copied: cbs2508ppd.png → CBS250-8PP-D.png
# Renamed and copied: cbs2508ppe2g.png → CBS250-8PP-E-2G.png
# Renamed and copied: cbs2508td.png → CBS250-8T-D.png
# Renamed and copied: cbs2508te2g.png → CBS250-8T-E-2G.png
# Renamed and copied: cbs35012np4x.png → CBS350-12NP-4X.png
# Renamed and copied: cbs35012xs.png → CBS350-12XS.png
# Renamed and copied: cbs35012xt.png → CBS350-12XT.png
# Renamed and copied: cbs35016fp2g.png → CBS350-16FP-2G.png
# Renamed and copied: cbs35016p2g.png → CBS350-16P-2G.png
# Renamed and copied: cbs35016pe2g.png → CBS350-16P-E-2G.png
# Renamed and copied: cbs35016t2g.png → CBS350-16T-2G.png
# Renamed and copied: cbs35016te2g.png → CBS350-16T-E-2G.png
# Renamed and copied: cbs35016xts.png → CBS350-16XTS.png
# Renamed and copied: cbs35024fp4g.png → CBS350-24FP-4G.png
# Renamed and copied: cbs35024fp4x.png → CBS350-24FP-4X.png
# Renamed and copied: cbs35024mgp4x.png → CBS350-24MGP-4X.png
# Renamed and copied: cbs35024ngp4x.png → CBS350-24NGP-4X.png
# Renamed and copied: cbs35024p4g.png → CBS350-24P-4G.png
# Renamed and copied: cbs35024p4x.png → CBS350-24P-4X.png
# Renamed and copied: cbs35024s4g.png → CBS350-24S-4G.png
# Renamed and copied: cbs35024t4g.png → CBS350-24T-4G.png
# Renamed and copied: cbs35024t4x.png → CBS350-24T-4X.png
# Renamed and copied: cbs35024xs.png → CBS350-24XS.png
# Renamed and copied: cbs35024xt.png → CBS350-24XT.png
# Renamed and copied: cbs35024xts.png → CBS350-24XTS.png
# Renamed and copied: cbs35048fp4g.png → CBS350-48FP-4G.png
# Renamed and copied: cbs35048fp4x.png → CBS350-48FP-4X.png
# Renamed and copied: cbs35048ngp4x.png → CBS350-48NGP-4X.png
# Renamed and copied: cbs35048p4g.png → CBS350-48P-4G.png
# Renamed and copied: cbs35048p4x.png → CBS350-48P-4X.png
# Renamed and copied: cbs35048t4g.png → CBS350-48T-4G.png
# Renamed and copied: cbs35048t4x.png → CBS350-48T-4X.png
# Renamed and copied: cbs35048xt4x.png → CBS350-48XT-4X.png
# Renamed and copied: cbs3508fp2g.png → CBS350-8FP-2G.png
# Renamed and copied: cbs3508fpe2g.png → CBS350-8FP-E-2G.png
# Renamed and copied: cbs3508mgp2x.png → CBS350-8MGP-2X.png
# Renamed and copied: cbs3508mp2x.png → CBS350-8MP-2X.png
# Renamed and copied: cbs3508p2g.png → CBS350-8P-2G.png
# Renamed and copied: cbs3508pe2g.png → CBS350-8P-E-2G.png
# Renamed and copied: cbs3508se2g.png → CBS350-8S-E-2G.png
# Renamed and copied: cbs3508te2g.png → CBS350-8T-E-2G.png
# Renamed and copied: cbs3508xt.png → CBS350-8XT.png
# Renamed and copied: ce1680016.png → CE16800-16.png
# Renamed and copied: ce168004.png → CE16800-4.png
# Renamed and copied: ce168008.png → CE16800-8.png
# Renamed and copied: ce16800x16.png → CE16800-X16.png
# Renamed and copied: ce16800x4.png → CE16800-X4.png
# Renamed and copied: ce16800x8.png → CE16800-X8.png
# Renamed and copied: ce98604cei.png → CE9860-4C-EI.png
# Renamed and copied: ce98604ceia.png → CE9860-4C-EI-A.png
# Renamed and copied: ce98d32cqa.png → CE98-D32CQ-A.png
# Renamed and copied: ce98d8dq.png → CE98-D8DQ.png
# Renamed and copied: cgpolt16t.png → CGP-OLT-16T.png
# Renamed and copied: cgpolt8t.png → CGP-OLT-8T.png
# Renamed and copied: cgpont1p.png → CGP-ONT-1P.png
# Renamed and copied: cgpont4p.png → CGP-ONT-4P.png
# Renamed and copied: cgpont4pv.png → CGP-ONT-4PV.png
# Renamed and copied: cgpont4pvc.png → CGP-ONT-4PVC.png
# Renamed and copied: cgpont4tvcwx.png → CGP-ONT-4TVCW-x.png
# Renamed and copied: cmicr4pc.png → CMICR-4PC.png
# Renamed and copied: cmicr4ps.png → CMICR-4PS.png
# Renamed and copied: cmicr4pt.png → CMICR-4PT.png
# Renamed and copied: connectrixds300b.png → Connectrix DS 300B.png
# Renamed and copied: connectrixds6505b.png → Connectrix DS 6505B.png
# Renamed and copied: connectrixds6510b.png → Connectrix DS 6510B.png
# Renamed and copied: connectrixds6520b.png → Connectrix DS 6520B.png
# Renamed and copied: connectrixds6610b.png → Connectrix DS 6610B.png
# Renamed and copied: connectrixds6620b.png → Connectrix DS 6620B.png
# Renamed and copied: connectrixds6630b.png → Connectrix DS 6630B.png
# Renamed and copied: connectrixmds9132t.png → Connectrix MDS 9132T.png
# Renamed and copied: connectrixmds9148s.png → Connectrix MDS 9148S.png
# Renamed and copied: connectrixmds9148t.png → Connectrix MDS 9148T.png
# Renamed and copied: connectrixmds9396s.png → Connectrix MDS 9396S.png
# Renamed and copied: connectrixmds9396t.png → Connectrix MDS 9396T.png
# Renamed and copied: connectrixmp7810b.png → Connectrix MP 7810B.png
# Renamed and copied: connectrixmp7840b.png → Connectrix MP 7840B.png
# Renamed and copied: crs1061c5s.png → CRS106-1C-5S.png
# Renamed and copied: crs1128p4sin.png → CRS112-8P-4S-IN.png
# Renamed and copied: crs3044xgin.png → CRS304-4XG-IN.png
# Renamed and copied: crs3051g4sin.png → CRS305-1G-4S+IN.png
# Renamed and copied: crs3091g8sin.png → CRS309-1G-8S+IN.png
# Renamed and copied: crs3101g5s4sin.png → CRS310-1G-5S-4S+IN.png
# Renamed and copied: crs3108g2sin.png → CRS310-8G+2S+IN.png
# Renamed and copied: crs3124c8xgrm.png → CRS312-4C+8XG-RM.png
# Renamed and copied: crs3171g16srm.png → CRS317-1G-16S+RM.png
# Renamed and copied: crs3208p8b4srm.png → CRS320-8P-8B-4S+RM.png
# Renamed and copied: crs32624g2sin.png → CRS326-24G-2S+IN.png
# Renamed and copied: crs32624g2srm.png → CRS326-24G-2S+RM.png
# Renamed and copied: crs32624s2qrm.png → CRS326-24S+2Q+RM.png
# Renamed and copied: crs3264c20g2qrm.png → CRS326-4C+20G+2Q+RM.png
# Renamed and copied: crs32824p4srm.png → CRS328-24P-4S+RM.png
# Renamed and copied: crs3284c20s4srm.png → CRS328-4C-20S-4S+RM.png
# Renamed and copied: crs35448g4s2qrm.png → CRS354-48G-4S+2Q+RM.png
# Renamed and copied: crs35448p4s2qrm.png → CRS354-48P-4S+2Q+RM.png
# Renamed and copied: crs5044xqin.png → CRS504-4XQ-IN.png
# Renamed and copied: crs5044xqout.png → CRS504-4XQ-OUT.png
# Renamed and copied: crs5108xs2xqin.png → CRS510-8XS-2XQ-IN.png
# Renamed and copied: crs51816xs2xqrm.png → CRS518-16XS-2XQ-RM.png
# Renamed and copied: crs5204xs16xqrm.png → CRS520-4XS-16XQ-RM.png
# Renamed and copied: css31816g2sin.png → CSS318-16G-2S+IN.png
# ...
# Renamed and copied: tpetg262es.png → TPE-TG262ES.png
# Renamed and copied: tpetg327.png → TPE-TG327.png
# Renamed and copied: tpetg350.png → TPE-TG350.png
# Renamed and copied: tpetg380.png → TPE-TG380.png
# Renamed and copied: tpetg44g.png → TPE-TG44g.png
# Renamed and copied: tpetg50es.png → TPE-TG50ES.png
# Renamed and copied: tpetg50g.png → TPE-TG50g.png
# Renamed and copied: tpetg51g.png → TPE-TG51g.png
# Renamed and copied: tpetg52.png → TPE-TG52.png
# Renamed and copied: tpetg611.png → TPE-TG611.png
# Renamed and copied: tpetg80g.png → TPE-TG80g.png
# Renamed and copied: tpetg81g.png → TPE-TG81g.png
# Renamed and copied: tpetg82es.png → TPE-TG82ES.png
# Renamed and copied: tpetg82g.png → TPE-TG82g.png
# Renamed and copied: tpetg83.png → TPE-TG83.png
# Renamed and copied: tpetg84.png → TPE-TG84.png
# Renamed and copied: Ultra.png → Ultra.png
# Renamed and copied: v3008p2tw.png → V300-8P-2T-W.png
# Renamed and copied: v3008p2x.png → V300-8P-2X.png
# Renamed and copied: v3008t2x.png → V300-8T-2X.png
# Renamed and copied: v300ht8t2x.png → V300HT-8T-2X.png
# Renamed and copied: v40024p10ge2.png → V400-24p-10GE2.png
# Renamed and copied: v40024t10ge2.png → V400-24t-10GE2.png
# Renamed and copied: v40048p10ge4.png → V400-48p-10GE4.png
# Renamed and copied: v40048t10ge4.png → V400-48t-10GE4.png
# Renamed and copied: vim52q.png → VIM5-2Q.png
# Renamed and copied: vim54x.png → VIM5-4X.png
# Renamed and copied: vim54xe.png → VIM5-4XE.png
# Renamed and copied: vim54ye.png → VIM5-4YE.png
# Renamed and copied: VSM4320C.png → VSM4320C.png
# Renamed and copied: vsp490012mxu12xe.png → VSP4900-12MXU-12XE.png
# Renamed and copied: vsp490024s.png → VSP4900-24S.png
# Renamed and copied: vsp490024xe.png → VSP4900-24XE.png
# Renamed and copied: vsp490048p.png → VSP4900-48P.png
# Renamed and copied: vsp740032c.png → VSP 7400-32C.png
# Renamed and copied: vsp740048y8c.png → VSP 7400-48Y-8C.png
# Renamed and copied: ws6503e.png → WS-6503-E.png
# Renamed and copied: ws6504e.png → WS-6504-E.png
# Renamed and copied: ws6506e.png → WS-6506-E.png
# Renamed and copied: ws6509e.png → WS-6509-E.png
# Renamed and copied: ws6509ve.png → WS-6509-V-E.png
# Renamed and copied: ws6513e.png → WS-6513-E.png
# Renamed and copied: wsc2960l16psll.png → WS-C2960L-16PS-LL.png
# Renamed and copied: wsc2960l16tsll.png → WS-C2960L-16TS-LL.png
# Renamed and copied: wsc2960l24pqll.png → WS-C2960L-24PQ-LL.png
# Renamed and copied: wsc2960l24psll.png → WS-C2960L-24PS-LL.png
# Renamed and copied: wsc2960l24tqll.png → WS-C2960L-24TQ-LL.png
# Renamed and copied: wsc2960l24tsll.png → WS-C2960L-24TS-LL.png
# Renamed and copied: wsc2960l48pqll.png → WS-C2960L-48PQ-LL.png
# Renamed and copied: wsc2960l48psll.png → WS-C2960L-48PS-LL.png
# Renamed and copied: wsc2960l48tqll.png → WS-C2960L-48TQ-LL.png
# Renamed and copied: wsc2960l48tsll.png → WS-C2960L-48TS-LL.png
# Renamed and copied: wsc2960l8psll.png → WS-C2960L-8PS-LL.png
# Renamed and copied: wsc2960l8tsll.png → WS-C2960L-8TS-LL.png
# Renamed and copied: wsc2960lsm16ps.png → WS-C2960L-SM-16PS.png
# Renamed and copied: wsc2960lsm16ts.png → WS-C2960L-SM-16TS.png
# Renamed and copied: wsc2960lsm24pq.png → WS-C2960L-SM-24PQ.png
# Renamed and copied: wsc2960lsm24ps.png → WS-C2960L-SM-24PS.png
# Renamed and copied: wsc2960lsm24tq.png → WS-C2960L-SM-24TQ.png
# Renamed and copied: wsc2960lsm24ts.png → WS-C2960L-SM-24TS.png
# Renamed and copied: wsc2960lsm48pq.png → WS-C2960L-SM-48PQ.png
# Renamed and copied: wsc2960lsm48ps.png → WS-C2960L-SM-48PS.png
# Renamed and copied: wsc2960lsm48tq.png → WS-C2960L-SM-48TQ.png
# Renamed and copied: wsc2960lsm48ts.png → WS-C2960L-SM-48TS.png
# Renamed and copied: wsc2960lsm8ps.png → WS-C2960L-SM-8PS.png
# Renamed and copied: wsc2960lsm8ts.png → WS-C2960L-SM-8TS.png
# Renamed and copied: wsc365012x48fd.png → WS-C3650-12X48FD.png
# Renamed and copied: wsc365012x48uq.png → WS-C3650-12X48UQ.png
# Renamed and copied: wsc365012x48ur.png → WS-C3650-12X48UR.png
# Renamed and copied: wsc365012x48uz.png → WS-C3650-12X48UZ.png
# Renamed and copied: wsc365024pd.png → WS-C3650-24PD.png
# Renamed and copied: wsc365024pdm.png → WS-C3650-24PDM.png
# Renamed and copied: wsc365024ps.png → WS-C3650-24PS.png
# Renamed and copied: wsc365024td.png → WS-C3650-24TD.png
# Renamed and copied: wsc365024ts.png → WS-C3650-24TS.png
# Renamed and copied: wsc365048fd.png → WS-C3650-48FD.png
# Renamed and copied: wsc365048fq.png → WS-C3650-48FQ.png
# Renamed and copied: wsc365048fqm.png → WS-C3650-48FQM.png
# Renamed and copied: wsc365048fs.png → WS-C3650-48FS.png
# Renamed and copied: wsc365048pd.png → WS-C3650-48PD.png
# Renamed and copied: wsc365048pq.png → WS-C3650-48PQ.png
# Renamed and copied: wsc365048ps.png → WS-C3650-48PS.png
# Renamed and copied: wsc365048td.png → WS-C3650-48TD.png
# Renamed and copied: wsc365048tq.png → WS-C3650-48TQ.png
# Renamed and copied: wsc365048ts.png → WS-C3650-48TS.png
# Renamed and copied: wsc36508x24pd.png → WS-C3650-8X24PD.png
# Renamed and copied: wsc36508x24uq.png → WS-C3650-8X24UQ.png
# Renamed and copied: wsc385012s.png → WS-C3850-12S.png
# Renamed and copied: wsc385012x48u.png → WS-C3850-12X48U.png
# Renamed and copied: wsc385012xs.png → WS-C3850-12XS.png
# Renamed and copied: wsc385024p.png → WS-C3850-24P.png
# Renamed and copied: wsc385024s.png → WS-C3850-24S.png
# Renamed and copied: wsc385024t.png → WS-C3850-24T.png
# Renamed and copied: wsc385024u.png → WS-C3850-24U.png
# Renamed and copied: wsc385024xs.png → WS-C3850-24XS.png
# Renamed and copied: wsc385024xu.png → WS-C3850-24XU.png
# Renamed and copied: wsc385048f.png → WS-C3850-48F.png
# Renamed and copied: wsc385048p.png → WS-C3850-48P.png
# Renamed and copied: wsc385048t.png → WS-C3850-48T.png
# Renamed and copied: wsc385048u.png → WS-C3850-48U.png
# Renamed and copied: wsc385048xs.png → WS-C3850-48XS.png
# Renamed and copied: x1008on.png → X1008-ON.png
# Renamed and copied: x1018on.png → X1018-ON.png
# Renamed and copied: x1026on.png → X1026-ON.png
# Renamed and copied: x1052on.png → X1052-ON.png
# Renamed and copied: x220-28GS.png → x220-28GS.png
# Renamed and copied: x220-52GP.png → x220-52GP.png
# Renamed and copied: x220-52GT.png → x220-52GT.png
# Renamed and copied: x230-10GP.png → x230-10GP.png
# Renamed and copied: x230-10GT.png → x230-10GT.png
# Renamed and copied: x230-18GP.png → x230-18GP.png
# Renamed and copied: x230-18GT.png → x230-18GT.png
# Renamed and copied: x230-28GP.png → x230-28GP.png
# Renamed and copied: x230-28GT.png → x230-28GT.png
# Renamed and copied: x230L-17GT.png → x230L-17GT.png
# Renamed and copied: x230L-26GT.png → x230L-26GT.png
# Renamed and copied: x240-10GHXm.png → x240-10GHXm.png
# Renamed and copied: x240-10GTXm.png → x240-10GTXm.png
# Renamed and copied: x240-26GHXm.png → x240-26GHXm.png
# Renamed and copied: x250-18XS.png → x250-18XS.png
# Renamed and copied: x250-28XS.png → x250-28XS.png
# Renamed and copied: x250-28XTm.png → x250-28XTm.png
# Renamed and copied: x320-10GH.png → x320-10GH.png
# Renamed and copied: x320-11GPT.png → x320-11GPT.png
# Renamed and copied: x330-10GTX.png → x330-10GTX.png
# Renamed and copied: x330-20GTX.png → x330-20GTX.png
# Renamed and copied: x330-28GTX.png → x330-28GTX.png
# Renamed and copied: x46548p.png → X465-48P.png
# Renamed and copied: x46548t.png → X465-48T.png
# Renamed and copied: x46548wx465i48w.png → X465-48W X465i-48W.png
# Renamed and copied: x530-10GHXm.png → x530-10GHXm.png
# Renamed and copied: x530-18GHXm.png → x530-18GHXm.png
# Renamed and copied: x530-28GPXm.png → x530-28GPXm.png
# Renamed and copied: x530-28GSX.png → x530-28GSX.png
# Renamed and copied: x530-28GTXm.png → x530-28GTXm.png
# Renamed and copied: x530-52GPXm.png → x530-52GPXm.png
# Renamed and copied: x530-52GTXm.png → x530-52GTXm.png
# Renamed and copied: x530DP-28GHXm.png → x530DP-28GHXm.png
# Renamed and copied: x530DP-52GHXm.png → x530DP-52GHXm.png
# Renamed and copied: x530L-10GHXm.png → x530L-10GHXm.png
# Renamed and copied: x530L-18GHXm.png → x530L-18GHXm.png
# Renamed and copied: x530L-28GPX.png → x530L-28GPX.png
# Renamed and copied: x530L-28GTX.png → x530L-28GTX.png
# Renamed and copied: x530L-52GPX.png → x530L-52GPX.png
# Renamed and copied: x530L-52GTX.png → x530L-52GTX.png
# Renamed and copied: x540L-28XS.png → x540L-28XS.png
# Renamed and copied: x540L-28XTm.png → x540L-28XTm.png
# Renamed and copied: x550-18XSPQm.png → x550-18XSPQm.png
# Renamed and copied: x550-18XSQ.png → x550-18XSQ.png
# Renamed and copied: x550-18XTQ.png → x550-18XTQ.png
# Renamed and copied: x59024t1q2c.png → X590-24t-1q-2c.png
# Renamed and copied: x59024x1q2c.png → X590-24x-1q-2c.png
# Renamed and copied: x62010x.png → X620-10x.png
# Renamed and copied: x62016x.png → X620–16x.png
# Renamed and copied: x670g248x4q.png → X670-G2-48x-4q.png
# Renamed and copied: x670g272x.png → X670-G2-72x.png
# Renamed and copied: x69048t2q4c.png → X690-48t-2q-4c.png
# Renamed and copied: x69048x2q4c.png → X690-48x-2q-4c.png
# Renamed and copied: x69548y8c.png → X695-48Y-8C.png
# Renamed and copied: x87032c.png → X870-32c.png
# Renamed and copied: x930-28GPX.png → x930-28GPX.png
# Renamed and copied: x930-28GSTX.png → x930-28GSTX.png
# Renamed and copied: x930-28GTX.png → x930-28GTX.png
# Renamed and copied: x930-52GPX.png → x930-52GPX.png
# Renamed and copied: x930-52GTX.png → x930-52GTX.png
# Renamed and copied: x950-28XSQ.png → x950-28XSQ.png
# Renamed and copied: x950-28XTQm.png → x950-28XTQm.png
# Renamed and copied: x950-52XSQ.png → x950-52XSQ.png
# Renamed and copied: x950-52XTQm.png → x950-52XTQm.png
# Renamed and copied: XA1440.png → XA1440.png
# Renamed and copied: XA1480.png → XA1480.png
# Renamed and copied: xgs101012.png → XGS1010-12.png
# Renamed and copied: xgs121012.png → XGS1210-12.png
# Renamed and copied: xgs125012.png → XGS1250-12.png
# Renamed and copied: xgs193028.png → XGS1930-28.png
# Renamed and copied: xgs193028hp.png → XGS1930-28HP.png
# Renamed and copied: xgs193052.png → XGS1930-52.png
# Renamed and copied: xgs193052hp.png → XGS1930-52HP.png
# Renamed and copied: xgs193528.png → XGS1935-28.png
# Renamed and copied: xgs193528hp.png → XGS1935-28HP.png
# Renamed and copied: xgs193552.png → XGS1935-52.png
# Renamed and copied: xgs193552hp.png → XGS1935-52HP.png
# Renamed and copied: xgs222030.png → XGS2220-30.png
# Renamed and copied: xgs222030f.png → XGS2220-30F.png
# Renamed and copied: xgs222030hp.png → XGS2220-30HP.png
# Renamed and copied: xgs222054.png → XGS2220-54.png
# Renamed and copied: xgs222054fp.png → XGS2220-54FP.png
# Renamed and copied: xgs222054hp.png → XGS2220-54HP.png
# Renamed and copied: xgs460032.png → XGS4600-32.png
# Renamed and copied: xgs460032f.png → XGS4600-32F.png
# Renamed and copied: xgs460052f.png → XGS4600-52F.png
# Renamed and copied: xh1680016.png → XH16800-16.png
# Renamed and copied: xh168008.png → XH16800-8.png
# Renamed and copied: xh8110or9110.png → XH8110 or 9110.png
# Renamed and copied: xh8210or9210.png → XH8210 or 9210.png
# Renamed and copied: XH9010.png → XH9010.png
# Renamed and copied: xh9030.png → XH9030.png
# Renamed and copied: xmg105.png → XMG-105.png
# Renamed and copied: xmg105hp.png → XMG-105HP.png
# Renamed and copied: xmg108.png → XMG-108.png
# Renamed and copied: xmg108hp.png → XMG-108HP.png
# Renamed and copied: xmg191510e.png → XMG1915-10E.png
# Renamed and copied: xmg191510ep.png → XMG1915-10EP.png
# Renamed and copied: xmg191518ep.png → XMG1915-18EP.png
# Renamed and copied: xmg193030.png → XMG1930-30.png
# Renamed and copied: xmg193030hp.png → XMG1930-30HP.png
# Renamed and copied: xpressprosw.png → XPress-Pro SW.png
# Renamed and copied: xs193010.png → XS1930-10.png
# Renamed and copied: xs193012f.png → XS1930-12F.png
# Renamed and copied: xs193012hp.png → XS1930-12HP.png
# Renamed and copied: xs380028.png → XS3800-28.png
# Renamed and copied: XS505M.png → XS505M.png
# Renamed and copied: XS508M.png → XS508M.png
# Renamed and copied: XS508TM.png → XS508TM.png
# Renamed and copied: XS512EM.png → XS512EM.png
# Renamed and copied: XS516TM.png → XS516TM.png
# Renamed and copied: XS724EM.png → XS724EM.png
# Renamed and copied: XS728T.png → XS728T.png
# Renamed and copied: XS748T.png → XS748T.png
# Renamed and copied: xs9108.png → XS9108.png
# Renamed and copied: XS916MXS.png → XS916MXS.png
# Renamed and copied: XS916MXT.png → XS916MXT.png
# Renamed and copied: XSM4216F.png → XSM4216F.png
# Renamed and copied: XSM4316PA.png → XSM4316PA.png
# Renamed and copied: XSM4316PB.png → XSM4316PB.png
# Renamed and copied: XSM4316S.png → XSM4316S.png
# Renamed and copied: XSM4324CS.png → XSM4324CS.png
# Renamed and copied: XSM4324FS.png → XSM4324FS.png
# Renamed and copied: XSM4324S.png → XSM4324S.png
# Renamed and copied: XSM4328CV.png → XSM4328CV.png
# Renamed and copied: XSM4328FV.png → XSM4328FV.png
# Renamed and copied: XSM4340CV.png → XSM4340CV.png
# Renamed and copied: XSM4340FV.png → XSM4340FV.png
# Renamed and copied: XSM4340V.png → XSM4340V.png
# Renamed and copied: XSM4344C.png → XSM4344C.png
# Renamed and copied: XSM4348CS.png → XSM4348CS.png
# Renamed and copied: XSM4348FS.png → XSM4348FS.png
# Renamed and copied: XSM4348S.png → XSM4348S.png
# Renamed and copied: xx87096x8c.png → XX870-96x-8c.png
# Renamed and copied: z9100on.png → Z9100-ON.png
# Renamed and copied: z9264fon.png → Z9264F-ON.png
# Renamed and copied: z9332fon.png → Z9332F-ON.png
# Renamed and copied: z9432fon.png → Z9432F-ON.png
# Renamed and copied: z9500on.png → Z9500-ON.png
# Renamed and copied: z9664fon.png → Z9664F-ON.png
# Renamed and copied: z9864fon.png → Z9864F-ON.png
# No match for: _HPE Networking Comware Switch 48SFP+ 6QSFP+ or 2QSFP28 5710 (JL585A).png
# No match for: _HPE Networking Instant On Switch_48p Gigabit 4p SFP 1830_(JL814A).png
# No match for: _HPE Networking_Instant On Switch 16p_Gigabit 1430_(R8R47A).png
# No match for: _Nexus 7009.png
# No match for: _XMG1930-30.png

# %%
# Create list of expected image filenames
import os
import pandas as pd
import re

# Function to normalize strings for comparison
def normalize(name):
    # Lowercase
    name = name.lower()
    # Remove spaces, underscores, dashes, and other non-alphanumeric chars
    name = re.sub(r'[\s_\-\.\(\)]', '', name)
    return name

# Path to your Excel file and images folder
excel_path = r'F:\UI\EXCELS\Switch\Switches.xlsx'  # Change this to your actual Excel file path
images_folder =  r'F:\UI\EXCELS\Switch\Switch_images'

# Read Excel
df = pd.read_excel(excel_path)

# Assuming the column with names is exactly 'Name'
excel_names = df['Name'].dropna().astype(str).tolist()

# Normalize Excel names
normalized_excel_names = {normalize(name): name for name in excel_names}

# Get all image filenames in the folder (without extension)
image_files = [f for f in os.listdir(images_folder) if f.lower().endswith('.png')]

# Normalize image filenames (remove .png and normalize)
normalized_image_names = set(normalize(os.path.splitext(f)[0]) for f in image_files)

# Find missing files by comparing normalized names
missing_normalized = [norm_name for norm_name in normalized_excel_names if norm_name not in normalized_image_names]

# Get original names of missing files from the dictionary
missing_original_names = [normalized_excel_names[n] for n in missing_normalized]

print(f"Total missing files: {len(missing_original_names)}")
print("Missing files:")
for name in missing_original_names:
    print(name)
# Out:
# Total missing files: 35
# Missing files:
# XS910/8
# HPE Aruba Networking CX 6300M 48p
# SR10 PTP/AVB Class8 PoE 4p 100G
# MACsec Switch (S0E91A)
# HPE Aruba Networking 6300M 24p
# HPE Smart Rate 1G/2.5G/5G/10G
# Class6 PoE and 2p 50G and 2p 25G
# Switch (R8S89A)
# HPE Aruba Networking 6300M 48p
# HPE Smart Rate 1G/2.5G/5G Class8
# PoE and 2p 50G and 2p 25G Switch
# (R8S90A)
# HPE Aruba Networking 6300M 48SR5 12p
#
# Class8 PoE and 36p Class6 PoE HPE Smart Rate
#
# 1G/2.5G/5G and 2p 50G and 2p 10G LRM support
#
# Switch (R8S91A)
# HPE Aruba Networking
#
# 6300M 48‑port
#
# HPE Smart Rate
#
# 1/2.5/5GbE Class 6 PoE
#
# and 4‑port SFP56 Switch
#
# (JL659A)
# HPE Aruba Networking
#
# 6300M 24‑port
#
# HPE Smart Rate
#
# 1/2.5/5GbE Class 6 PoE
#
# and 4‑port SFP56 Switch
#
# (JL660A)
# HPE Aruba Networking 6300L 48p Smart
# Rate 1G/2.5G/5G Class8/6 PoE 2p 50G and 2p 10G LRM L2 Switch (S3L77A)
# HPE Aruba Networking 6300L 24p
#
# Smart Rate 1G/2.5G/5G/10G Class6
#
# PoE 2p 50G and 2p 25G L2 Switch
#
# (S3L75A)
# HPE Aruba Networking 6300L 48p
#
# Smart Rate 1G/2.5G/5G Class8
#
# PoE 2p 50G and 2p 25G L2 Switch
#
# (S3L76A)
# HPE Aruba Networking 6200F
#
# 12G Class4 PoE 2G/2SFP+139W
#
# Switch (R8Q72A)
# HPE Aruba Networking 6100
#
# 12G Class4 PoE 2G/2SFP + 139W
#
# Switch (JL679A)
# HPE Aruba Networking 6000 12G
#
# Class4 PoE 2G/2SFP 139W Switch
#
# (R8N89A)
# R9A29A HPE Aruba Networking 9300 32D 32p
#
# 100/200/400G QSFP-DD 2p 10G SFP+ Front-to-Back
#
# 6xR8Z99A Front-to-Back Fans
#
# 2xR8Z97A Front-to-Back 1500W 100-240VAC Power
#
# Supply
# R9A30A HPE Aruba Networking 9300 32D 32p
#
# 100/200/400G QSFP-DD 2p 10G SFP+ Back-to-Front
#
# 6xR9A00A Back-to-Front Fans
#
# 2xR8Z98A Back-to-Front 1500W 100-240VAC Power
#
# Supply
# HPE Aruba Networking 8320 48p
#
# 10G SFP/SFP+ and 6p 40G QSFP+
#
# with X472 5 Fans 2 Power Supply
#
# Switch Bundle (JL479A)
# HPE Aruba Networking 8320
#
# 48p 1G/10GBASE‑T and 6p 40G
#
# QSFP+ with X472 5 Fans
#
# 2 Power Supply Switch
#
# Bundle (JL581A)
# HPE 5406R-44G-PoE+/2SFP+ (No PSU) v2 zl2 Switch (J9823A)
# HPE 5412R-92G-PoE+/2SFP+ (No PSU) v2 zl2 Switch (J9825A)
# HPE 5406R-44G-PoE+/4SFP (No PSU) v2 zl2 Switch (J9824A)
# HPE 5406R-8XGT/8SFP+ (No PSU) v2 zl2 Switch (J9868A)
# Aruba 5406R 8-port 1/2.5/5/10GBASE-T PoE+ / 8-port SFP+ (No PSU) v3 zl2 Switch (JL002A)
# HPE Networking Comware Switch 24p 10/100/1000BASE-T 4p SFP+ 1 Exp 2 PS Slot 5520HI (R8M25A)
#
# HPE Networking Comware Switch 48G 10/100/1000BASE-T 4 10G/1G BASE-X 5520HI (R8M26A)
#
# HPE Networking Comware Switch 24 SFP 4 10G/1G BASE-X SFP+ 1 Exp slot 2 Fan Tray 2 PS 5520HI
# (R8M27A)
# HPE Networking Comware Switch 24 10/100/1000BASE-T 4 10G/1G BASE-X SFP+ 1 Exp 2 Fan Tray 2
# PS 5520HI (R8M28A)
# HPE Aruba Networking 2930F 12G PoE+ 2G/2SFP+ Switch (JL693A)
#
# HPE Networking Instant On Switch
# 8p Gigabit CL4 4p SR2.5G CL6 PoE
# 2p 10GBT 2p SFP+ 480W 1960
# (S0F35A)
# S7703/S7703-PoE
# S7706/S7706-PoE
# QFX10002-72Q-DC
# TL-SG2210P V3.20
#
# TL-SL2428P V4.20
# Flex 2.5G PoE
# Flex Mini 2.5G
